# %% [markdown]
# # Glaucoma uncertainty quantification — Colab quickstart
#
# This notebook runs the cleaned manuscript code package. Adjust paths if needed.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Adjust this path to the repository folder in Google Drive
REPO_DIR = '/content/drive/My Drive/glaucoma_uq_plosone_code'
DATA_DIR = '/content/drive/My Drive/Combi_datasets/'
OUTPUT_DIR = '/content/drive/My Drive/glaucoma_uq_outputs'

import sys, os
sys.path.insert(0, os.path.join(REPO_DIR, 'src'))

# %%
# Optional: install required packages if your Colab runtime is missing them
# !pip install -r "{REPO_DIR}/requirements.txt"

# %%
# Run the full manuscript pipeline
# !python "{REPO_DIR}/src/run_pipeline.py" \
    --data_dir "{DATA_DIR}" \
    --output_dir "{OUTPUT_DIR}" \
    --epochs 20 \
    --mc_runs 50

# %% [markdown]
# ## Outputs
#
# After the run, check `OUTPUT_DIR` for CSV files, NPZ MC predictions and manuscript figures.
